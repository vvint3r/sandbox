# %%
import pandas as pd

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "apollo_index/companies_enterprise"

# List to store DataFrames
dfs = []

# Loop through each file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith(".csv"):  # Process only CSV files
        file_path = os.path.join(folder_path, file_name)
        df = pd.read_csv(file_path)  # Read each CSV file
        dfs.append(df)  # Append DataFrame to the list

# Concatenate all DataFrames into one
merged_df = pd.concat(dfs, ignore_index=True)

# Save the merged DataFrame to a new CSV file
output_file_path = os.path.join(folder_path, "merged_companies_enterprise.csv")
merged_df.to_csv(output_file_path, index=False)

print(f"Merged CSV file saved to: {output_file_path}")
# Out:
# Merged CSV file saved to: apollo_index/companies_enterprise\merged_companies_enterprise.csv

# %%
merged_df
# Out:
#           Company Company Name for Emails Account Stage  Lists  # Employees  \
# 0        Ceridian                Ceridian          Cold    NaN         5400
# 1     CenturyLink             CenturyLink          Cold    NaN        25000
# 2      Altimetrik              Altimetrik          Cold    NaN        10000
# 3       BCforward               BCforward          Cold    NaN         1500
# 4       Instacart               Instacart          Cold    NaN        21000
# ...           ...                     ...           ...    ...          ...
# 1502  Bumble Inc.                  Bumble          Cold    NaN         1300
# 1503     Talkdesk                Talkdesk          Cold    NaN         1300
# 1504          PTW                     PTW          Cold    NaN         2900
# 1505  Blue Yonder             Blue Yonder          Cold    NaN         6700
# 1506  SentinelOne             SentinelOne          Cold    NaN         2800
#
# ...
